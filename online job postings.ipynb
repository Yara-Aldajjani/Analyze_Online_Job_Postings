# %% [markdown]
# # online job postings

# %% [markdown]
# ![WSHP-1%20%28dragged%29.tiff](attachment:WSHP-1%20%28dragged%29.tiff)

# %% [markdown]
# <br><br><br><br>
# ## Gather

# %%
import zipfile
import pandas as pd
import matplotlib as plt
import numpy as np
# %matplotlib inline

# %%
with zipfile.ZipFile('online-job-postings.zip', 'r') as myzip:
    myzip.extractall()

# %%
df= pd.read_csv('online-job-postings.csv')
df
# Out:
#                                                  jobpost          date  \
# 0      AMERIA Investment Consulting Company\r\nJOB TI...   Jan 5, 2004
# 1      International Research & Exchanges Board (IREX...   Jan 7, 2004
# 2      Caucasus Environmental NGO Network (CENN)\r\nJ...   Jan 7, 2004
# 3      Manoff Group\r\nJOB TITLE:  BCC Specialist\r\n...   Jan 7, 2004
# 4      Yerevan Brandy Company\r\nJOB TITLE:  Software...  Jan 10, 2004
# ...                                                  ...           ...
# 18996  Technolinguistics NGO\r\n\r\n\r\nTITLE:  Senio...  Dec 28, 2015
# 18997  "Coca-Cola Hellenic Bottling Company Armenia" ...  Dec 30, 2015
# 18998  "Coca-Cola Hellenic Bottling Company Armenia" ...  Dec 30, 2015
# 18999  San Lazzaro   LLC\r\n\r\n\r\nTITLE:  Head of O...  Dec 30, 2015
# 19000  "Kamurj" UCO CJSC\r\n\r\n\r\nTITLE:  Lawyer in...  Dec 30, 2015
#
#                                                    Title  \
# ...

# %% [markdown]
# <br><br><br>
# ## Assess

# %%
df.head()
# Out:
#                                              jobpost          date  \
# 0  AMERIA Investment Consulting Company\r\nJOB TI...   Jan 5, 2004
# 1  International Research & Exchanges Board (IREX...   Jan 7, 2004
# 2  Caucasus Environmental NGO Network (CENN)\r\nJ...   Jan 7, 2004
# 3  Manoff Group\r\nJOB TITLE:  BCC Specialist\r\n...   Jan 7, 2004
# 4  Yerevan Brandy Company\r\nJOB TITLE:  Software...  Jan 10, 2004
#
#                                                Title  \
# 0                            Chief Financial Officer
# 1  Full-time Community Connections Intern (paid i...
# 2                                Country Coordinator
# 3                                     BCC Specialist
# 4                                 Software Developer
#
#                                            Company AnnouncementCode Term  \
# 0             AMERIA Investment Consulting Company              NaN  NaN
# 1  International Research & Exchanges Board (IREX)              NaN  NaN
# ...

# %%
df.tail()
# Out:
#                                                  jobpost          date  \
# 18996  Technolinguistics NGO\r\n\r\n\r\nTITLE:  Senio...  Dec 28, 2015
# 18997  "Coca-Cola Hellenic Bottling Company Armenia" ...  Dec 30, 2015
# 18998  "Coca-Cola Hellenic Bottling Company Armenia" ...  Dec 30, 2015
# 18999  San Lazzaro   LLC\r\n\r\n\r\nTITLE:  Head of O...  Dec 30, 2015
# 19000  "Kamurj" UCO CJSC\r\n\r\n\r\nTITLE:  Lawyer in...  Dec 30, 2015
#
#                                  Title  \
# 18996  Senior Creative UX/ UI Designer
# 18997     Category Development Manager
# 18998    Operational Marketing Manager
# 18999  Head of Online Sales Department
# 19000       Lawyer in Legal Department
#
#                                                  Company AnnouncementCode  \
# 18996                              Technolinguistics NGO              NaN
# 18997  "Coca-Cola Hellenic Bottling Company Armenia" ...              NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19001 entries, 0 to 19000
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   jobpost           19001 non-null  object
#  1   date              19001 non-null  object
#  2   Title             18973 non-null  object
#  3   Company           18994 non-null  object
#  4   AnnouncementCode  1208 non-null   object
#  5   Term              7676 non-null   object
#  6   Eligibility       4930 non-null   object
#  7   Audience          640 non-null    object
#  8   StartDate         9675 non-null   object
#  9   Duration          10798 non-null  object
#  10  Location          18969 non-null  object
#  11  JobDescription    15109 non-null  object
#  12  JobRequirment     16479 non-null  object
#  13  RequiredQual      18517 non-null  object
#  14  Salary            9622 non-null   object
#  15  ApplicationP      18941 non-null  object
# ...

# %%
df['Year'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        2004
# 1        2004
# 2        2004
# 3        2004
# 4        2004
#          ...
# 18996    2015
# 18997    2015
# 18998    2015
# 18999    2015
# 19000    2015
# Name: Year, Length: 19001, dtype: int64>

# %% [markdown]
# - Missing values (NaN)
# - StartDate Inconsistency (ASAP)
# - Nondescriptive column headers

# %% [markdown]
# <br><br><br>
# ## Clean
# <br><br><br>**Define**<br>
# - Select the records that have "As soon as possible" and "Immediately",etc. in the StartDate column and change it to "ASAP".
# - Select the column headers that are misspelled and nondescriptive and change them to full name without any space in between.
#
# <br><br><br>**code**

# %%
df_clean= df.copy()

# %% [markdown]
# Select the column headers that are misspelled and nondescriptive and change them to full name without any space in between:

# %%
df_clean.rename(columns={'RequiredQual':'RequiredQualifications', 'ApplicationP':'ApplicationProcedure',
                        'AboutC':'AboutCompany','Attach':'Attachments','JobRequirment':'JobRequirements'},
                inplace=True)

# %%
df_clean.StartDate.value_counts()
# Out:
# ASAP                      4754
# Immediately                773
# As soon as possible        543
# Upon hiring                261
# Immediate                  259
#                           ...
# 5 July 2007                  1
# 01 July 2007                 1
# 15 November 2012             1
# 16 October 2009, 19:00       1
# First quarter of 2012        1
# Name: StartDate, Length: 1186, dtype: int64

# %%
# Out:
# 49

# %%
asap_list = ['Immediately', 'As soon as possible', 'Upon hiring',
             'Immediate', 'Immediate employment', 'As soon as possible.', 'Immediate job opportunity',
             '"Immediate employment, after passing the interview."',
             'ASAP preferred', 'Employment contract signature date',
             'Immediate employment opportunity', 'Immidiately', 'ASA',
             'Asap', '"The position is open immediately but has a flexible start date depending on the candidates earliest availability."',
             'Immediately upon agreement', '20 November 2014 or ASAP',
             'immediately', 'Immediatelly',
             '"Immediately upon selection or no later than November 15, 2009."',
             'Immediate job opening', 'Immediate hiring', 'Upon selection',
             'As soon as practical', 'Immadiate', 'As soon as posible',
             'Immediately with 2 months probation period',
             '12 November 2012 or ASAP', 'Immediate employment after passing the interview',
             'Immediately/ upon agreement', '01 September 2014 or ASAP',
             'Immediately or as per agreement', 'as soon as possible',
             'As soon as Possible', 'in the nearest future', 'immediate',
             '01 April 2014 or ASAP', 'Immidiatly', 'Urgent',
             'Immediate or earliest possible', 'Immediate hire',
             'Earliest  possible', 'ASAP with 3 months probation period.',
             'Immediate employment opportunity.', 'Immediate employment.',
             'Immidietly', 'Imminent', 'September 2014 or ASAP', 'Imediately']

for phrase in asap_list:
    df_clean.StartDate.replace( asap_list,'ASAP' , inplace=True)

# %% [markdown]
# <br>**Test**

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19001 entries, 0 to 19000
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   jobpost                 19001 non-null  object
#  1   date                    19001 non-null  object
#  2   Title                   18973 non-null  object
#  3   Company                 18994 non-null  object
#  4   AnnouncementCode        1208 non-null   object
#  5   Term                    7676 non-null   object
#  6   Eligibility             4930 non-null   object
#  7   Audience                640 non-null    object
#  8   StartDate               9675 non-null   object
#  9   Duration                10798 non-null  object
#  10  Location                18969 non-null  object
#  11  JobDescription          15109 non-null  object
#  12  JobRequirements         16479 non-null  object
#  13  RequiredQualifications  18517 non-null  object
# ...

# %%
df_clean.StartDate.value_counts()
# Out:
# ASAP                                                   6856
# 01 September 2012                                        31
# March 2006                                               27
# November 2006                                            22
# January 2010                                             19
#                                                        ...
# 15 November 2012                                          1
# Preferably 15 February 2005, latest 01 March  2005.       1
# 16 October 2009, 19:00                                    1
# 07 February 2005                                          1
# First quarter of 2012                                     1
# Name: StartDate, Length: 1140, dtype: int64

# %%
for phrase in asap_list:
    assert phrase not in df_clean.StartDate.values

# %% [markdown]
# Since there's no error message, that means the process went will.

# %% [markdown]
# <br><br><br>
# ## Analysis and Visualization

# %%
# number of ASAP start dates:
number_ASAP= df_clean.StartDate.value_counts()['ASAP']
number_ASAP
# Out:
# 6856

# %%
# number of non-empty start date:
NonEmpty_StartDate= df_clean.StartDate.count()
NonEmpty_StartDate
# Out:
# 9675

# %%
ASAP_percentage=number_ASAP/NonEmpty_StartDate
ASAP_percentage
# Out:
# 0.7086304909560723

# %%
#the percentage of postings that are looking for someone to start urgently 
print("The postings that are looking for someone to start urgently is about {:.2%}".format(ASAP_percentage))
# Out:
# The postings that are looking for someone to start urgently is about 70.86%

# %%
# plotting the distribution of start dates in the data:
labels= np.full(len(df_clean.StartDate.value_counts()),"", dtype=object)
labels[0]='ASAP'
cmap = plt.cm.prism
colors = cmap(np.linspace(0., 1., len(df_clean.StartDate.value_counts())))
df_clean.StartDate.value_counts().plot(kind="pie", labels=labels, colors=colors)
# Out:
# <AxesSubplot:ylabel='StartDate'>
