# %% [markdown]
# # online job postings

# %% [markdown]
# ![WSHP-1%20%28dragged%29.tiff](attachment:WSHP-1%20%28dragged%29.tiff)

# %% [markdown]
# <br><br><br><br>
# ## Gather

# %% [markdown]
# <br><br><br>
# ## Assess

# %% [markdown]
# <br><br><br>
# ## Clean
# <br><br><br>**Define**
# <br><br><br>**code**

# %% [markdown]
# <br>**Test**
